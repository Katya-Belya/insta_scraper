# %%
import pytesseract
print(pytesseract.get_tesseract_version())
# Out:
# 5.5.0.20241111

# %%
from PIL import Image
import pytesseract

image_path = "../data/raw_images/dyke_party_01.jpg"
img = Image.open(image_path).convert("L")

text = pytesseract.image_to_string(img)
print("----- OCR OUTPUT -----")
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import pytesseract
#       4 image_path = "../data/raw_images/dyke_party_01.jpg"
# ----> 5 img = Image.open(image_path).convert("L")
#       7 text = pytesseract.image_to_string(img)
#       8 print("----- OCR OUTPUT -----")
#
# File ~\OneDrive\Documents\insta_scraper\.venv\Lib\site-packages\PIL\Image.py:3512, in open(fp, mode, formats)
#    3510 if is_path(fp):
#    3511     filename = os.fspath(fp)
# -> 3512     fp = builtins.open(filename, "rb")
#    3513     exclusive_fp = True
#    3514 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw_images/dyke_party_01.jpg'
